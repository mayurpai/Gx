# %%
import pandas as pd

# %%
df = pd.read_csv('./data/survey_results_public.csv')
schema_df = pd.read_csv('./data/survey_results_schema.csv')

# %%
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
df.shape
# Out:
# (89184, 84)

# %%
df.describe()
# Out:
#          ResponseId     CompTotal       WorkExp  ConvertedCompYearly
# count  89184.000000  4.822500e+04  43579.000000         4.801900e+04
# mean   44592.500000  1.036807e+42     11.405126         1.031101e+05
# std    25745.347541  2.276847e+44      9.051989         6.814188e+05
# min        1.000000  0.000000e+00      0.000000         1.000000e+00
# 25%    22296.750000  6.300000e+04      5.000000         4.390700e+04
# 50%    44592.500000  1.150000e+05      9.000000         7.496300e+04
# 75%    66888.250000  2.300000e+05     16.000000         1.216410e+05
# max    89184.000000  5.000000e+46     50.000000         7.435143e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89184 entries, 0 to 89183
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           89184 non-null  int64
#  1   Q120                                 89184 non-null  object
#  2   MainBranch                           89184 non-null  object
#  3   Age                                  89184 non-null  object
#  4   Employment                           87898 non-null  object
#  5   RemoteWork                           73810 non-null  object
#  6   CodingActivities                     73764 non-null  object
#  7   EdLevel                              87973 non-null  object
#  8   LearnCode                            87663 non-null  object
#  9   LearnCodeOnline                      70084 non-null  object
#  10  LearnCodeCoursesCert                 37076 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# ResponseId                                 0
# Q120                                       0
# MainBranch                                 0
# Age                                        0
# Employment                              1286
# RemoteWork                             15374
# CodingActivities                       15420
# EdLevel                                 1211
# LearnCode                               1521
# LearnCodeOnline                        19100
# LearnCodeCoursesCert                   52108
# YearsCode                               1749
# YearsCodePro                           23048
# DevType                                12312
# OrgSize                                24141
# PurchaseInfluence                      24220
# TechList                               28333
# BuyNewTool                              6175
# Country                                 1211
# Currency                               23850
# CompTotal                              40959
# ...

# %%
pd.set_option('display.max_rows', 85)
pd.set_option('display.max_columns', 85)

# %%
df.tail(10)
# Out:
#        ResponseId     Q120                      MainBranch  \
# 89174       89175  I agree  I am a developer by profession
# 89175       89176  I agree  I am a developer by profession
# 89176       89177  I agree  I am a developer by profession
# 89177       89178  I agree  I am a developer by profession
# 89178       89179  I agree  I am a developer by profession
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 89174     18-24 years old                                Employed, full-time
# 89175     25-34 years old                                Employed, full-time
# 89176     18-24 years old                                 Student, full-time
# ...

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
schema_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2   QID310                  Q310
# 3   QID312                  Q120
# 4     QID1                    S1
# 5     QID2            MainBranch
# 6   QID127                   Age
# 7   QID296            Employment
# 8   QID308            RemoteWork
# 9   QID297      CodingActivities
# 10  QID190                    S2
# 11   QID25               EdLevel
# 12  QID276             LearnCode
# 13  QID281       LearnCodeOnline
# 14  QID306  LearnCodeCoursesCert
# 15   QID32             YearsCode
# 16   QID34          YearsCodePro
# 17   QID31               DevType
# 18   QID29               OrgSize
# 19  QID278     PurchaseInfluence
# 20  QID322              TechList
# 21  QID279            BuyNewTool
# 22    QID6               Country
# 23   QID50              Currency
# 24   QID51             CompTotal
# 25   QID61                    S3
# 26  QID233              Language
# ...

# %%
df.keys()
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
'WorkExp' in df.keys()
# Out:
# True

# %%
df.WorkExp
# Out:
# 0         NaN
# 1        10.0
# 2        23.0
# 3         7.0
# 4         6.0
#          ...
# 89179     NaN
# 89180     NaN
# 89181     NaN
# 89182     NaN
# 89183    14.0
# Name: WorkExp, Length: 89184, dtype: float64

# %%
df.loc[df['WorkExp']>20]
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 2               3  I agree                     I am a developer by profession
# 5               6  I agree                     I am a developer by profession
# 36             37  I agree                     I am a developer by profession
# 48             49  I agree                     I am a developer by profession
# 120           121  I agree                     I am a developer by profession
# ...           ...      ...                                                ...
# 89150       89151  I agree  I used to be a developer by profession, but no...
# 89162       89163  I agree                     I am a developer by profession
# 89169       89170  I agree                     I am a developer by profession
# 89172       89173  I agree                     I am a developer by profession
# 89178       89179  I agree                     I am a developer by profession
#
# ...

# %%
df.loc[0:4, 'Age']
# Out:
# 0    18-24 years old
# 1    25-34 years old
# 2    45-54 years old
# 3    25-34 years old
# 4    25-34 years old
# Name: Age, dtype: object

# %%
df.loc[0:3]
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                                Remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# 0                                                NaN
# 1  Hobby;Contribute to open-source projects;Boots...
# 2  Hobby;Professional development or self-paced l...
# 3                                              Hobby
#
# ...

# %%
df.iloc[0:4]
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                                Remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# 0                                                NaN
# 1  Hobby;Contribute to open-source projects;Boots...
# 2  Hobby;Professional development or self-paced l...
# 3                                              Hobby
#
# ...

# %%
schema_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2   QID310                  Q310
# 3   QID312                  Q120
# 4     QID1                    S1
# 5     QID2            MainBranch
# 6   QID127                   Age
# 7   QID296            Employment
# 8   QID308            RemoteWork
# 9   QID297      CodingActivities
# 10  QID190                    S2
# 11   QID25               EdLevel
# 12  QID276             LearnCode
# 13  QID281       LearnCodeOnline
# 14  QID306  LearnCodeCoursesCert
# 15   QID32             YearsCode
# 16   QID34          YearsCodePro
# 17   QID31               DevType
# 18   QID29               OrgSize
# 19  QID278     PurchaseInfluence
# 20  QID322              TechList
# 21  QID279            BuyNewTool
# 22    QID6               Country
# 23   QID50              Currency
# 24   QID51             CompTotal
# 25   QID61                    S3
# 26  QID233              Language
# ...

# %%
schema_df.set_index('qid', inplace=True)
schema_df.sort_index(inplace=True)

# %%
schema_df
# Out:
#                        qname  \
# qid
# QID1                      S1
# QID100           SOVisitFreq
# QID101             SOAccount
# QID102            SOPartFreq
# QID106                SOComm
# QID12               MetaInfo
# QID127                   Age
# QID131                    S7
# QID132          SurveyLength
# QID133            SurveyEase
# QID16                     S0
# QID190                    S2
# QID2              MainBranch
# QID233              Language
# QID25                EdLevel
# QID262              Database
# QID263              Platform
# QID264              Webframe
# QID265              MiscTech
# QID266            NEWSOSites
# QID274        NEWCollabTools
# QID275             ToolsTech
# QID276             LearnCode
# QID278     PurchaseInfluence
# QID279            BuyNewTool
# QID281       LearnCodeOnline
# QID282      OfficeStackAsync
# QID286          SOTeamsUsage
# QID287                ICorPM
# QID288               WorkExp
# ...

# %%
schema_df.reset_index(inplace=True)

# %%
schema_df
# Out:
#        qid                 qname  \
# 0     QID1                    S1
# 1   QID100           SOVisitFreq
# 2   QID101             SOAccount
# 3   QID102            SOPartFreq
# 4   QID106                SOComm
# 5    QID12              MetaInfo
# 6   QID127                   Age
# 7   QID131                    S7
# 8   QID132          SurveyLength
# 9   QID133            SurveyEase
# 10   QID16                    S0
# 11  QID190                    S2
# 12    QID2            MainBranch
# 13  QID233              Language
# 14   QID25               EdLevel
# 15  QID262              Database
# 16  QID263              Platform
# 17  QID264              Webframe
# 18  QID265              MiscTech
# 19  QID266            NEWSOSites
# 20  QID274        NEWCollabTools
# 21  QID275             ToolsTech
# 22  QID276             LearnCode
# 23  QID278     PurchaseInfluence
# 24  QID279            BuyNewTool
# 25  QID281       LearnCodeOnline
# 26  QID282      OfficeStackAsync
# ...

# %%
schema_df.head()
# Out:
#       qid        qname                                           question  \
# 0    QID1           S1  <span style="font-size:22px; font-family: aria...
# 1  QID100  SOVisitFreq  How frequently would you say you visit Stack O...
# 2  QID101    SOAccount              Do you have a Stack Overflow account?
# 3  QID102   SOPartFreq  How frequently would you say you participate i...
# 4  QID106       SOComm  Do you consider yourself a member of the Stack...
#
#   force_resp type selector
# 0      False   DB       TB
# 1      False   MC     SAVR
# 2      False   MC     SAVR
# 3      False   MC     SAVR
# 4      False   MC     SAVR

# %%
filt = schema_df['selector'] == 'TB'

# %%
schema_df[filt]
# Out:
#        qid qname                                           question  \
# 0     QID1    S1  <span style="font-size:22px; font-family: aria...
# 7   QID131    S7  <span style="font-size:22px;"><strong>Final Qu...
# 10   QID16    S0  <div><span style="font-size:19px;"><strong>Hel...
# 11  QID190    S2  <span style="font-size:22px; font-family: aria...
# 46  QID295    S6  <span style="font-size:22px; font-family: aria...
# 55  QID310  Q310  <div><span style="font-size:19px;"><strong>You...
# 57  QID313    S5  <span style="font-size:22px; font-family: aria...
# 75   QID61    S3  <span style="font-size:22px; font-family: aria...
# 77   QID91    S4  <span style="font-size:22px; font-family: aria...
#
#    force_resp type selector
# 0       False   DB       TB
# 7       False   DB       TB
# 10      False   DB       TB
# 11      False   DB       TB
# 46      False   DB       TB
# 55      False   DB       TB
# 57      False   DB       TB
# 75      False   DB       TB
# ...

# %%
schema_df.loc[schema_df.selector == 'TB']
# Out:
#        qid qname                                           question  \
# 0     QID1    S1  <span style="font-size:22px; font-family: aria...
# 7   QID131    S7  <span style="font-size:22px;"><strong>Final Qu...
# 10   QID16    S0  <div><span style="font-size:19px;"><strong>Hel...
# 11  QID190    S2  <span style="font-size:22px; font-family: aria...
# 46  QID295    S6  <span style="font-size:22px; font-family: aria...
# 55  QID310  Q310  <div><span style="font-size:19px;"><strong>You...
# 57  QID313    S5  <span style="font-size:22px; font-family: aria...
# 75   QID61    S3  <span style="font-size:22px; font-family: aria...
# 77   QID91    S4  <span style="font-size:22px; font-family: aria...
#
#    force_resp type selector
# 0       False   DB       TB
# 7       False   DB       TB
# 10      False   DB       TB
# 11      False   DB       TB
# 46      False   DB       TB
# 55      False   DB       TB
# 57      False   DB       TB
# 75      False   DB       TB
# ...

# %%
filt_1 = schema_df['qname'] == 'S1'  
filt_2 = schema_df['qname'] == 'S2'

# %%
schema_df.loc[filt_1 | filt_2]
# Out:
#        qid qname                                           question  \
# 0     QID1    S1  <span style="font-size:22px; font-family: aria...
# 11  QID190    S2  <span style="font-size:22px; font-family: aria...
#
#    force_resp type selector
# 0       False   DB       TB
# 11      False   DB       TB

# %%
df.loc[df.WorkExp > 10, ['ResponseId', 'WorkExp']]
# Out:
#        ResponseId  WorkExp
# 2               3     23.0
# 5               6     22.0
# 15             16     15.0
# 19             20     14.0
# 28             29     18.0
# ...           ...      ...
# 89172       89173     24.0
# 89173       89174     15.0
# 89177       89178     12.0
# 89178       89179     22.0
# 89183       89184     14.0
#
# [18215 rows x 2 columns]

# %%
countries = ["India", "Brazil"]
df.loc[df["Country"].isin(countries), ["Country", "WorkExp"]]
# Out:
#       Country  WorkExp
# 9       India      NaN
# 31     Brazil      NaN
# 66      India      NaN
# 78      India      NaN
# 82      India      5.0
# ...       ...      ...
# 89162  Brazil     25.0
# 89164   India      2.0
# 89165   India      3.0
# 89167   India      2.0
# 89179  Brazil      NaN
#
# [7667 rows x 2 columns]

# %%
python_lang_filter = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)

# %%
df[python_lang_filter]
# Out:
#        ResponseId     Q120                      MainBranch  \
# 1               2  I agree  I am a developer by profession
# 7               8  I agree  I am a developer by profession
# 9              10  I agree  I am a developer by profession
# 10             11  I agree  I am a developer by profession
# 11             12  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89172       89173  I agree  I am a developer by profession
# 89176       89177  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
#
#                       Age                              Employment  \
# 1         25-34 years old                     Employed, full-time
# 7         25-34 years old                     Employed, full-time
# ...

# %%
df['SOAccount'].isnull().sum()
df['SOAccount'].fillna(0, inplace=True)

# %%
df.shape
# Out:
# (89184, 84)

# %%
df.drop(df[df['SOAccount'] == 0].index, inplace=True)

# %%
df.shape
# Out:
# (87852, 84)

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# 5               6  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89178       89179  I agree  I am a developer by profession
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 1         25-34 years old                                Employed, full-time
# 2         45-54 years old                                Employed, full-time
# ...

# %%
df['SOAccount'] = df['SOAccount'].map({'Yes': 1, 'No': 0})

# %%
df['SOAccount']
# Out:
# 1        1.0
# 2        1.0
# 3        1.0
# 4        0.0
# 5        1.0
#         ...
# 89178    1.0
# 89179    1.0
# 89180    1.0
# 89182    0.0
# 89183    1.0
# Name: SOAccount, Length: 87852, dtype: float64

# %%
schema_df = pd.read_csv('./data/survey_results_schema.csv', index_col='qname')

# %%
schema_df
# Out:
#                          qid  \
# qname
# S0                     QID16
# MetaInfo               QID12
# Q310                  QID310
# Q120                  QID312
# S1                      QID1
# MainBranch              QID2
# Age                   QID127
# Employment            QID296
# RemoteWork            QID308
# CodingActivities      QID297
# S2                    QID190
# EdLevel                QID25
# LearnCode             QID276
# LearnCodeOnline       QID281
# LearnCodeCoursesCert  QID306
# YearsCode              QID32
# YearsCodePro           QID34
# DevType                QID31
# OrgSize                QID29
# PurchaseInfluence     QID278
# TechList              QID322
# BuyNewTool            QID279
# Country                 QID6
# Currency               QID50
# CompTotal              QID51
# S3                     QID61
# Language              QID233
# Database              QID262
# Platform              QID263
# Webframe              QID264
# ...

# %%
temp_schema_df = schema_df

# %%
temp_schema_df.drop(columns=['qid', 'type'], inplace=True)

# %%
temp_schema_df
# Out:
#                                                                question  \
# qname
# S0                    <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo                                              Browser Meta Info
# Q310                  <div><span style="font-size:19px;"><strong>You...
# Q120
# S1                    <span style="font-size:22px; font-family: aria...
# MainBranch            Which of the following options best describes ...
# Age                                                 What is your age? *
# Employment            Which of the following best describes your cur...
# RemoteWork            Which best describes your current work situation?
# CodingActivities      Which of the following best describes the code...
# S2                    <span style="font-size:22px; font-family: aria...
# EdLevel               Which of the following best describes the high...
# LearnCode              How do you learn to code? Select all that apply.
# ...

# %%
schema_df.head()
# Out:
#                                                    question force_resp  \
# qname
# S0        <div><span style="font-size:19px;"><strong>Hel...      False
# MetaInfo                                  Browser Meta Info      False
# Q310      <div><span style="font-size:19px;"><strong>You...      False
# Q120                                                              True
# S1        <span style="font-size:22px; font-family: aria...      False
#
#          selector
# qname
# S0             TB
# MetaInfo  Browser
# Q310           TB
# Q120         SAVR
# S1             TB

# %%
df.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
# 5           6  I agree  I am a developer by profession  35-44 years old
#
#                                           Employment  \
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
# 5                                Employed, full-time
#
#                              RemoteWork  \
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# 4                                Remote
# ...

# %%
df['SOAccount'].mean()
# Out:
# 0.8193077873918417

# %%
df['SOAccount'].median()
# Out:
# 1.0

# %%
df.describe()
# Out:
#          ResponseId     CompTotal     SOAccount       WorkExp  \
# count  87852.000000  4.820600e+04  80900.000000  43557.000000
# mean   44476.500387  1.037215e+42      0.819308     11.407535
# std    25750.689456  2.277296e+44      0.384765      9.052257
# min        2.000000  0.000000e+00      0.000000      0.000000
# 25%    22175.750000  6.300000e+04      1.000000      5.000000
# 50%    44373.500000  1.150000e+05      1.000000      9.000000
# 75%    66795.250000  2.300000e+05      1.000000     16.000000
# max    89184.000000  5.000000e+46      1.000000     50.000000
#
#        ConvertedCompYearly
# count         4.800000e+04
# mean          1.031310e+05
# std           6.815522e+05
# min           1.000000e+00
# 25%           4.390700e+04
# 50%           7.496300e+04
# 75%           1.216728e+05
# max           7.435143e+07

# %%
df['SOAccount'].count()
# Out:
# 80900

# %%
df.shape
# Out:
# (87852, 84)

# %%
df['SOAccount'].isnull().sum()
# Out:
# 6952

# %%
df['TBranch'].value_counts()
# Out:
# TBranch
# Yes    43841
# No     21856
# Name: count, dtype: int64

# %%
df['Industry'].value_counts()
# Out:
# Industry
# Information Services, IT, Software Development, or other Technology    18157
# Financial Services                                                      4421
# Other                                                                   4010
# Manufacturing, Transportation, or Supply Chain                          2607
# Healthcare                                                              2215
# Retail and Consumer Services                                            1955
# Higher Education                                                        1241
# Advertising Services                                                     786
# Insurance                                                                707
# Oil & Gas                                                                276
# Legal Services                                                           210
# Wholesale                                                                184
# Name: count, dtype: int64

# %%
df['Industry'].value_counts(normalize=True)
# Out:
# Industry
# Information Services, IT, Software Development, or other Technology    0.493813
# Financial Services                                                     0.120237
# Other                                                                  0.109059
# Manufacturing, Transportation, or Supply Chain                         0.070902
# Healthcare                                                             0.060241
# Retail and Consumer Services                                           0.053170
# Higher Education                                                       0.033751
# Advertising Services                                                   0.021377
# Insurance                                                              0.019228
# Oil & Gas                                                              0.007506
# Legal Services                                                         0.005711
# Wholesale                                                              0.005004
# ...

# %%
df['TBranch'].value_counts(normalize=True)
# Out:
# TBranch
# Yes    0.667321
# No     0.332679
# Name: proportion, dtype: float64

# %%
country_group = df.groupby(['Country'])

# %%
country_group.get_group('India').head()
# Out:
#     ResponseId     Q120                      MainBranch              Age  \
# 9           10  I agree  I am a developer by profession  25-34 years old
# 66          67  I agree  I am a developer by profession  25-34 years old
# 78          79  I agree  I am a developer by profession  18-24 years old
# 82          83  I agree  I am a developer by profession  25-34 years old
# 85          86  I agree  I am a developer by profession  25-34 years old
#
#                             Employment                            RemoteWork  \
# 9   Not employed, but looking for work                                   NaN
# 66                 Employed, full-time  Hybrid (some remote, some in-person)
# 78                 Employed, full-time                                Remote
# 82                 Employed, full-time  Hybrid (some remote, some in-person)
# 85                 Employed, full-time                             In-person
#
#                             CodingActivities  \
# ...

# %%
df['Country'].value_counts()
# Out:
# Country
# United States of America                                18625
# Germany                                                  7322
# India                                                    5606
# United Kingdom of Great Britain and Northern Ireland     5547
# Canada                                                   3505
#                                                         ...
# Samoa                                                       1
# Central African Republic                                    1
# Grenada                                                     1
# San Marino                                                  1
# Saint Vincent and the Grenadines                            1
# Name: count, Length: 185, dtype: int64

# %%
india_filtered = df['Country'] == 'India'
df[india_filtered].shape
# Out:
# (5606, 84)

# %%
df.loc[india_filtered]['TBranch'].value_counts()
# Out:
# TBranch
# Yes    2941
# No      802
# Name: count, dtype: int64

# %%
country_group['TBranch'].value_counts().loc['India']
# Out:
# TBranch
# Yes    2941
# No      802
# Name: count, dtype: int64

# %%
country_group['TBranch'].value_counts(normalize=True).loc['India']
# Out:
# TBranch
# Yes    0.785733
# No     0.214267
# Name: proportion, dtype: float64

# %%
country_group['SOAccount'].agg(['mean', 'median']).loc['India']
# Out:
# mean      0.879314
# median    1.000000
# Name: India, dtype: float64

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# Country
# United States of America                                18625
# Germany                                                  7322
# India                                                    5606
# United Kingdom of Great Britain and Northern Ireland     5547
# Canada                                                   3505
#                                                         ...
# Samoa                                                       1
# Central African Republic                                    1
# Grenada                                                     1
# San Marino                                                  1
# Saint Vincent and the Grenadines                            1
# Name: count, Length: 185, dtype: int64

# %%
country_uses_python = country_group['LanguageHaveWorkedWith'].apply(
    lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              22
# Albania                                  19
# Algeria                                  34
# Andorra                                   5
# Angola                                    4
#                                        ...
# Venezuela, Bolivarian Republic of...     42
# Viet Nam                                173
# Yemen                                     8
# Zambia                                   11
# Zimbabwe                                 19
# Name: LanguageHaveWorkedWith, Length: 185, dtype: int64

# %%
python_df = pd.concat(
    [country_respondents, country_uses_python], axis='columns', sort=False)
python_df
# Out:
#                                                     count  \
# Country
# United States of America                            18625
# Germany                                              7322
# India                                                5606
# United Kingdom of Great Britain and Northern Ir...   5547
# Canada                                               3505
# ...                                                   ...
# Samoa                                                   1
# Central African Republic                                1
# Grenada                                                 1
# San Marino                                              1
# Saint Vincent and the Grenadines                        1
#
#                                                     LanguageHaveWorkedWith
# Country
# United States of America                                             10053
# Germany                                                               3684
# ...

# %%
python_df['PctKnowsPython'] = (
    python_df['LanguageHaveWorkedWith']/python_df['count']) * 100
python_df
# Out:
#                                                     count  \
# Country
# United States of America                            18625
# Germany                                              7322
# India                                                5606
# United Kingdom of Great Britain and Northern Ir...   5547
# Canada                                               3505
# ...                                                   ...
# Samoa                                                   1
# Central African Republic                                1
# Grenada                                                 1
# San Marino                                              1
# Saint Vincent and the Grenadines                        1
#
#                                                     LanguageHaveWorkedWith  \
# Country
# United States of America                                             10053
# Germany                                                               3684
# ...

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)

# %%
python_df
# Out:
#                                   count  LanguageHaveWorkedWith  \
# Country
# Saint Vincent and the Grenadines      1                       1
# Lesotho                               4                       4
# San Marino                            1                       1
# Grenada                               1                       1
# Samoa                                 1                       1
# ...                                 ...                     ...
# Suriname                              4                       0
# Central African Republic              1                       0
# Bahamas                               2                       0
# Djibouti                              2                       0
# Monaco                                2                       0
#
#                                   PctKnowsPython
# Country
# Saint Vincent and the Grenadines           100.0
# Lesotho                                    100.0
# ...

# %%
python_df.loc['India']
# Out:
# count                     5606.000000
# LanguageHaveWorkedWith    2784.000000
# PctKnowsPython              49.661077
# Name: India, dtype: float64

# %%
schema_df
# Out:
#                                                                question  \
# qname
# S0                    <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo                                              Browser Meta Info
# Q310                  <div><span style="font-size:19px;"><strong>You...
# Q120
# S1                    <span style="font-size:22px; font-family: aria...
# MainBranch            Which of the following options best describes ...
# Age                                                 What is your age? *
# Employment            Which of the following best describes your cur...
# RemoteWork            Which best describes your current work situation?
# CodingActivities      Which of the following best describes the code...
# S2                    <span style="font-size:22px; font-family: aria...
# EdLevel               Which of the following best describes the high...
# LearnCode              How do you learn to code? Select all that apply.
# ...

# %%
df.isnull().sum()
# Out:
# ResponseId                                 0
# Q120                                       0
# MainBranch                                 0
# Age                                        0
# Employment                                69
# RemoteWork                             14124
# CodingActivities                       14165
# EdLevel                                    0
# LearnCode                                278
# LearnCodeOnline                        17816
# LearnCodeCoursesCert                   50803
# YearsCode                                490
# YearsCodePro                           21761
# DevType                                11043
# OrgSize                                22854
# PurchaseInfluence                      22934
# TechList                               27045
# BuyNewTool                              4896
# Country                                    0
# Currency                               22597
# CompTotal                              39646
# ...

# %%
df['YearsCode'].unique()
# Out:
# array(['18', '27', '12', '6', '21', '4', '5', '20', '14', '10', '15',
#        '11', '3', '24', '8', '13', 'Less than 1 year', '16', '33', '22',
#        '30', '32', '7', '35', '28', '40', '17', nan, '29', '19',
#        'More than 50 years', '9', '38', '26', '34', '25', '2', '45', '23',
#        '31', '43', '1', '48', '41', '50', '39', '42', '37', '36', '44',
#        '46', '49', '47'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)
df['YearsCode'].replace('More than 50 years', 51, inplace=True)
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].unique()
# Out:
# array([18., 27., 12.,  6., 21.,  4.,  5., 20., 14., 10., 15., 11.,  3.,
#        24.,  8., 13.,  0., 16., 33., 22., 30., 32.,  7., 35., 28., 40.,
#        17., nan, 29., 19., 51.,  9., 38., 26., 34., 25.,  2., 45., 23.,
#        31., 43.,  1., 48., 41., 50., 39., 42., 37., 36., 44., 46., 49.,
#        47.])

# %%
df['YearsCode'].fillna(df['YearsCode'].mean(), inplace=True)

# %%
df['YearsCode'].unique()
# Out:
# array([18.        , 27.        , 12.        ,  6.        , 21.        ,
#         4.        ,  5.        , 20.        , 14.        , 10.        ,
#        15.        , 11.        ,  3.        , 24.        ,  8.        ,
#        13.        ,  0.        , 16.        , 33.        , 22.        ,
#        30.        , 32.        ,  7.        , 35.        , 28.        ,
#        40.        , 17.        , 13.96968934, 29.        , 19.        ,
#        51.        ,  9.        , 38.        , 26.        , 34.        ,
#        25.        ,  2.        , 45.        , 23.        , 31.        ,
#        43.        ,  1.        , 48.        , 41.        , 50.        ,
#        39.        , 42.        , 37.        , 36.        , 44.        ,
#        46.        , 49.        , 47.        ])

# %%
df['YearsCode'].mean()
# Out:
# 13.969689338614044

# %%
df['YearsCode'].median()
# Out:
# 11.0
